# %% [markdown]
# # Conclusion

# %% [markdown]
# > In this notebook we will be discussing the findings of the data and the model, reviewing the problem statement, and measuring our success.

# %% [markdown]
# ---

# %% [markdown]
# ## Findings

# %% [markdown]
# 1.   Neural Netorks can predict brain cancer in MRI scans with high accuracy.
# 2.   Global Average Pooling is necessary for Grad-CAM to function.
# 3. The weights of the model seemed to be affected by extreme brightness and darkness in MRI scans.
# 4. Adjusting the data by rotating the images, flipping them, and increasing/decreasing contrast seemed to worsen the model's performance and learning.

# %% [markdown]
# ---

# %% [markdown]
# ## Problem Statement review

# %% [markdown]
# ### **Using Neural Networks to Predict if an MRI scan of a Brain contains a tumor and detect where it is located.**
#
# The model performs well, it can predict with 0.95 accuracy and 0.19 loss. Another model had lower loss, but it decreased the accuracy. I chose higher accuracy because the difference was negligible to my eyes.
#
# Grad-CAM worked! It doees seem to give weight to where tumors are located so it displays well in the heatmaps generated from the data.
#
# ### **A neural network can be used to accurately predict if brain cancer is in an MRI scan, and give its assumption of where it might be located in the image.**
